# %%
# !git clone https://github.com/giovaniceotto/RocketPy.git
import os
# Out:
# fatal: destination path 'RocketPy' already exists and is not an empty directory.

# %%
import sys; 
print(sys.version)
# Out:
# 3.9.15 | packaged by conda-forge | (main, Nov 22 2022, 08:45:29)
# [GCC 10.4.0]

# %%
# !pip install --upgrade cffi
# !pip install rocketpy --pre netCDF4

import sys
# Out:
# Requirement already satisfied: cffi in /srv/conda/lib/python3.9/site-packages (1.16.0)
# Requirement already satisfied: pycparser in /srv/conda/lib/python3.9/site-packages (from cffi) (2.21)
# Requirement already satisfied: rocketpy in /srv/conda/lib/python3.9/site-packages (1.2.0)
# Requirement already satisfied: netCDF4 in /srv/conda/lib/python3.9/site-packages (1.6.5)
# Requirement already satisfied: numpy>=1.13 in /srv/conda/lib/python3.9/site-packages (from rocketpy) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /srv/conda/lib/python3.9/site-packages (from rocketpy) (1.10.0)
# Requirement already satisfied: simplekml in /srv/conda/lib/python3.9/site-packages (from rocketpy) (1.3.6)
# Requirement already satisfied: pytz in /srv/conda/lib/python3.9/site-packages (from rocketpy) (2024.1)
# Requirement already satisfied: requests in /srv/conda/lib/python3.9/site-packages (from rocketpy) (2.31.0)
# Requirement already satisfied: matplotlib>=3.0 in /srv/conda/lib/python3.9/site-packages (from rocketpy) (3.7.3)
# Requirement already satisfied: certifi in /srv/conda/lib/python3.9/site-packages (from netCDF4) (2022.12.7)
# Requirement already satisfied: cftime in /srv/conda/lib/python3.9/site-packages (from netCDF4) (1.6.3)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (1.2.0)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (8.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (6.1.1)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (4.49.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.9/site-packages (from requests->rocketpy) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.9/site-packages (from requests->rocketpy) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/lib/python3.9/site-packages (from requests->rocketpy) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0->rocketpy) (3.17.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->rocketpy) (1.16.0)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#get_ipython().run_line_magic('matplotlib', 'widget')

# %%
pip install rocketcea
# Out:
# Requirement already satisfied: rocketcea in /srv/conda/lib/python3.9/site-packages (1.1.34)
# Requirement already satisfied: matplotlib in /srv/conda/lib/python3.9/site-packages (from rocketcea) (3.7.3)
# Requirement already satisfied: scipy in /srv/conda/lib/python3.9/site-packages (from rocketcea) (1.10.0)
# Requirement already satisfied: numpy in /srv/conda/lib/python3.9/site-packages (from rocketcea) (1.26.4)
# Requirement already satisfied: future in /srv/conda/lib/python3.9/site-packages (from rocketcea) (1.0.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (6.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (8.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (4.49.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib->rocketcea) (23.2)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->rocketcea) (3.17.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->rocketcea) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in /srv/conda/lib/python3.9/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
pip install numpy matplotlib
# Out:
# Requirement already satisfied: numpy in /srv/conda/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /srv/conda/lib/python3.9/site-packages (3.7.3)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jsonpickle
# Out:
# Requirement already satisfied: jsonpickle in /srv/conda/lib/python3.9/site-packages (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install windrose
# Out:
# Requirement already satisfied: windrose in /srv/conda/lib/python3.9/site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.21 in /srv/conda/lib/python3.9/site-packages (from windrose) (1.26.4)
# Requirement already satisfied: matplotlib>=3 in /srv/conda/lib/python3.9/site-packages (from windrose) (3.7.3)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (4.49.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (3.1.1)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (0.12.1)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (8.3.2)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (23.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3->windrose) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3->windrose) (3.17.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3->windrose) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install simplekml
# Out:
# Requirement already satisfied: simplekml in /srv/conda/lib/python3.9/site-packages (1.3.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade cffi
# Out:
# Requirement already satisfied: cffi in /srv/conda/lib/python3.9/site-packages (1.16.0)
# Requirement already satisfied: pycparser in /srv/conda/lib/python3.9/site-packages (from cffi) (2.21)

# %%
pip install --upgrade rocketpy
# Out:
# Requirement already satisfied: rocketpy in /srv/conda/lib/python3.9/site-packages (1.2.0)
# Requirement already satisfied: matplotlib>=3.0 in /srv/conda/lib/python3.9/site-packages (from rocketpy) (3.7.3)
# Requirement already satisfied: simplekml in /srv/conda/lib/python3.9/site-packages (from rocketpy) (1.3.6)
# Requirement already satisfied: netCDF4>=1.6.4 in /srv/conda/lib/python3.9/site-packages (from rocketpy) (1.6.5)
# Requirement already satisfied: requests in /srv/conda/lib/python3.9/site-packages (from rocketpy) (2.31.0)
# Requirement already satisfied: numpy>=1.13 in /srv/conda/lib/python3.9/site-packages (from rocketpy) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /srv/conda/lib/python3.9/site-packages (from rocketpy) (1.10.0)
# Requirement already satisfied: pytz in /srv/conda/lib/python3.9/site-packages (from rocketpy) (2024.1)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (23.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (6.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (4.49.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (0.12.1)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (8.3.2)
# Requirement already satisfied: cftime in /srv/conda/lib/python3.9/site-packages (from netCDF4>=1.6.4->rocketpy) (1.6.3)
# Requirement already satisfied: certifi in /srv/conda/lib/python3.9/site-packages (from netCDF4>=1.6.4->rocketpy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.9/site-packages (from requests->rocketpy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.9/site-packages (from requests->rocketpy) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/lib/python3.9/site-packages (from requests->rocketpy) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0->rocketpy) (3.17.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->rocketpy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install timezonefinder
# Out:
# Requirement already satisfied: timezonefinder in /srv/conda/lib/python3.9/site-packages (6.4.1)
# Requirement already satisfied: numpy<2,>=1.25 in /srv/conda/lib/python3.9/site-packages (from timezonefinder) (1.26.4)
# Requirement already satisfied: h3<4,>=3.7.6 in /srv/conda/lib/python3.9/site-packages (from timezonefinder) (3.7.6)
# Requirement already satisfied: setuptools>=65.5 in /srv/conda/lib/python3.9/site-packages (from timezonefinder) (69.1.1)
# Requirement already satisfied: cffi<2,>=1.15.1 in /srv/conda/lib/python3.9/site-packages (from timezonefinder) (1.16.0)
# Requirement already satisfied: pycparser in /srv/conda/lib/python3.9/site-packages (from cffi<2,>=1.15.1->timezonefinder) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime
from time import process_time, perf_counter, time
import glob

import numpy as np
from numpy.random import normal, uniform, choice
from IPython.display import display

from rocketpy import Rocket, motors, simulation, environment, mathutils
from rocketpy.rocket import rocket
from rocketpy.motors import liquid_motor, tank, tank_geometry, fluid
from rocketpy.simulation import flight
from rocketpy.environment import environment
from rocketpy.mathutils import function

# %% [markdown]
# If you are using Jupyter Notebooks, it is recommended to run the following line to make matplotlib plots which will be shown later interactive and higher quality.

# %%
# %config InlineBackend.figure_formats = ['svg']
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
mpl.rcParams["figure.figsize"] = [8, 5]
mpl.rcParams["figure.dpi"] = 120
mpl.rcParams["font.size"] = 14
mpl.rcParams["legend.fontsize"] = 14
mpl.rcParams["figure.titlesize"] = 14

# %% [markdown]
# ## Setting Up Thrust Curve

# %%
import rocketcea
import os
import numpy as np
import scipy
from scipy.optimize import minimize
import tkinter as tk
import matplotlib.pyplot as plt
import matplotlib
print(matplotlib.matplotlib_fname())
from rocketcea.cea_obj import CEA_Obj
import pandas as pd
import math
import datetime

class propellant:
    def __init__(self,name, density, viscosity,tank_length, tank_radius, temperature):
        self.density = density
        self.viscosity = viscosity
        self.temp = temperature
        self.rad = tank_radius
        self.length = tank_length
        self.name = name
        return None
    def __str__(self) -> str:
        return self.name
# Out:
# /srv/conda/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
#matplotlib widget

# %%
#Fluid Properties (SI units)
rho_LOX = 1140.0
rho_ETH = 798.0

#System Test Data Results
CdA_inj_LOX = 0.000007537562547 #Test For Cd
CdA_inj_ETH = 0.0000135882885 #Test For Cd

CdA_feed_LOX = 0.000003850288211 #Test For Cd
CdA_feed_ETH = 0.000002212011972#Test For Cd

#Hydraulic Resistance Terms
R_ox_inj = 1/(2*(CdA_inj_LOX**2)) #dP=Rhyd*mdot^2/rho
R_eth_inj = 1/(2*(CdA_inj_ETH**2)) #dP=Rhyd*mdot^2/rho

R_ox_feed = 1/(2*(CdA_feed_LOX**2)) #dP=Rhyd*mdot^2/rho
R_eth_feed = 1/(2*(CdA_feed_ETH**2)) #dP=Rhyd*mdot^2/rho

R_ox = R_ox_inj + R_ox_feed #Equivalent Hydraulic System Resistance
R_eth = R_eth_inj + R_ox_feed #Equivalent Hydraulic System Resistance

#Tank Properties
gamma_tanks = 1.41 #1.41=GN2, 1.67=GHe
V_oxtank = 6.926 #L
V_ethtank = 7.57 #L

V_oxinit = 4.2 #L OPTMIMIZE THIS
V_ethinit = 3.25 #L OPTIMIZE THIS

V_oxgas = V_oxtank-V_oxinit
V_ethgas = V_ethtank - V_ethinit

#Initial Tank Pressures
P_tank_ox_psi = 800 #psia
P_oxtank = P_tank_ox_psi*6895 #Pa

P_tank_eth_psi = 600 #psia
P_ethtank = P_tank_eth_psi*6895 #Pa

#define cstar efficiency: completeion of energy release. See RPE Pg64
Efficiency = 0.91
chamber = CEA_Obj(propName="", oxName="LOX", fuelName="C2H5OH") #initializs CEA object

#define Throat Diameter, Area
Dt = 27.54/1000 #m
At = (Dt**2)/4*math.pi

# Initialize Array
Residual = []

#create Chamber Pressure Guess Array
Pc_test_psi = np.linspace(100.0, (max(P_tank_ox_psi, P_tank_eth_psi)-1), 100) #psia
Pc_test = Pc_test_psi*6895 #Pa

#solve residual for each pressure guess
for i in range(len(Pc_test)):

    #solve mass flow from fluid resistances
    mdot_ox = ((1/R_ox)*rho_LOX*(P_oxtank - Pc_test[i]))**(1/2)
    mdot_eth = ((1/R_eth)*rho_ETH*(P_ethtank - Pc_test[i]))**(1/2)
    mdot_fluid = mdot_ox + mdot_eth
    #get OF ratio
    OF_ratio_test = mdot_ox/mdot_eth

    #solve mass flow from CEA
    Cstar_fps = chamber.get_Cstar(Pc=Pc_test_psi[i], MR=OF_ratio_test) #see RPE pg64
    Cstar = Cstar_fps*0.3048 #m
    mdot_CEA = Pc_test[i]*At/(Cstar*Efficiency) #kg/s

    #compare residual, append to array
    error = (mdot_CEA-mdot_fluid)/mdot_CEA
    Residual.append(abs(error))

    plt.plot(Pc_test_psi[:i+1], Residual[:i+1])
    plt.xlabel('Chamber Pressure Guess (psia)')
    plt.ylabel('Residual Error (abs(Ratio/1))')
    plt.title('Chamber Pressure - Residual Solution Space')
    plt.grid(True)


# Display the final plot after the loop
plt.show()

def Calculate_Residual(Pc, P_oxtank, P_ethtank):
    #solve mass flow from fluid resistances
    mdot_ox = ((1/R_ox)*rho_LOX*(P_oxtank - (Pc*6895)))**(1/2)
    mdot_eth = ((1/R_eth)*rho_ETH*(P_ethtank - (Pc*6895)))**(1/2)
    mdot_fluid = mdot_ox + mdot_eth
    #get OF ratio
    OF_ratio = mdot_ox/mdot_eth
    #solve mass flow from CEA
    Cstar_fps = chamber.get_Cstar(Pc = Pc[0], MR = OF_ratio[0]) #see RPE pg64
    Cstar = float(Cstar_fps*0.3048) #m/s
    if Cstar == 0:
        print("CSTAR ZERO")
        print(f"PC = {Pc[0]}")
        mdot_CEA_res = Pc*6895*At/(abs(Cstar)*Efficiency)
    else:
        mdot_CEA_res = (Pc*6895)*At/(Cstar*Efficiency) #kg/s

    #compare residual, append to array
    error = (mdot_CEA_res-mdot_fluid)/mdot_CEA_res

    global OF_ratio_glob
    OF_ratio_glob = float(OF_ratio[0])

    global mdot_total_glob
    mdot_total_glob = float(mdot_fluid[0])

    if OF_ratio > 2.5: #tank pressure drop eqs breaking
        error = 5000
        print("OF RATIO ERROR")

    return abs(error)

def GradientDescent(guess, P_oxtank, P_ethtank):
    # Use scipy optimize minimize with residual function to find Chamber Pressure
    result = minimize(
        Calculate_Residual,
        guess,
        args = (P_oxtank, P_ethtank),
        bounds = [(85, min([P_oxtank/6895, P_ethtank/6895]))],
    )
    P_chamber = result.x[0]
    # t = type(P_chamber)
    #print(f"Pchamb TYPE {t}")
    OF = OF_ratio_glob
    isp = chamber.estimate_Ambient_Isp(Pc=P_chamber,MR=OF,eps=4.35)[0]
    thrust = 9.8*isp*(mdot_total_glob)/1000 #kN
    print(f"Thrust {thrust}")
    massflow_total = mdot_total_glob
    print(f"massflow {massflow_total}")
    #print(f"PC {P_chamber/6895} and MR {OF_ratio} at {i*dt}")

    return P_chamber, thrust, OF, massflow_total
# Out:
# /tmp/ipykernel_218/1257844181.py:60: RuntimeWarning: invalid value encountered in scalar power
#   mdot_eth = ((1/R_eth)*rho_ETH*(P_ethtank - Pc_test[i]))**(1/2)

# %%
#reference thrust curve
iterations = 250
time = np.linspace(0, 20, iterations) #200 pts from 0 to 15 seconds
dt = float(time[1]-time[0])
print(f"TIMESTEP {dt}")
OF_array = []
Thrust_array = []
P_chamber_array = []
mdtot_array = []
fin = 0
for i in range(len(time)): #perform this for every timestep in the profile

    if i == 0:
        Pc_guess = 325
    else:
        Pc_guess = P_chamber_last-5

    P_chamber, Thrust, OF, md_tot = GradientDescent(Pc_guess, P_oxtank, P_ethtank)
    md_ox = md_tot/(
        1+1/OF)
    md_eth = md_tot-md_ox
    Ox_inj_dp = (R_ox_inj)*(md_ox**2)/rho_LOX / 6894
    print(f"OX_INJ: {Ox_inj_dp}")
    OX_FEED_dP = (R_ox_feed)*(md_ox**2)/rho_LOX / 6894
    print(f"OX_FEED_dP: {OX_FEED_dP}")
    # ETH_inj_dp = (1/R_eth_inj)*(md_eth**2)/rho_ETH / 6894
    # print(f"ETH_INJ: {ETH_inj_dp}")

    #print(f"Timestep {dt}")
    masslost_ox = md_ox*dt
    masslost_eth = md_eth*dt
    #print(f"masslostox {masslost_ox}")

    #print(f"Voxgas(L) {V_oxgas}")
    V_oxgas_next = V_oxgas + (masslost_ox/(rho_LOX*0.001))
    V_ethgas_next = V_ethgas + (masslost_eth/(rho_ETH*0.001))
    #print(f"Voxgasnext(L) {V_oxgas_next}")

    P_oxtank = P_oxtank*((V_oxgas/V_oxgas_next)**gamma_tanks)
    P_ethtank = P_ethtank*((V_ethgas/V_ethgas_next)**gamma_tanks)
    # print(f"Oxtank = {P_oxtank/6895}[psi] ... Ethtank = {P_ethtank/6895}[psi] at {i*dt}")

    V_oxgas = V_oxgas_next
    V_ethgas = V_oxgas_next

    mdtot_array.append(md_tot)
    OF_array.append(OF)
    Thrust_array.append(Thrust)
    P_chamber_array.append(P_chamber)
    assert len(Thrust_array) == len(P_chamber_array)
    P_chamber_last = P_chamber

    if P_chamber>(0.90*P_oxtank/6895) or P_chamber>(0.90*P_oxtank/6895):
        OxDrop = (P_oxtank/6895)/P_chamber
        ETHDrop = (P_ethtank/6895)/P_chamber
        print(f"Flow Stability Violated with {OxDrop}% LOXratio and {ETHDrop}% ETHratio")
        break

    if V_oxgas>=(V_oxtank-V_oxtank/500) or V_ethgas>=(V_ethtank-V_ethtank/500):
        oxrem = V_oxtank-V_oxgas
        ethrem = V_ethtank-V_ethgas
        print(f"Burn finished with {oxrem}L LOX and {ethrem}L ETH at Time {i*dt}s")
        break

# Create the subplots and plot the data
fig, axs = plt.subplots(2, 2)
sc = axs[0, 0].plot(time[0:len(Thrust_array)], Thrust_array)
axs[0, 0].set_title("Thrust Curve")
axs[0, 0].set_xlabel("Time(s)")
axs[0, 0].set_ylabel("Thrust(kN)")

axs[0, 1].plot(time[0:len(Thrust_array)], P_chamber_array)
axs[0, 1].set_title("Chamber Pressure")
axs[0, 1].set_xlabel("Time(s)")
axs[0, 1].set_ylabel("Pchamber (psi)")

axs[1, 0].plot(time[0:len(Thrust_array)], mdtot_array)
axs[1, 0].set_title("Total Mass Flow")
axs[1, 0].set_xlabel("Time(s)")
axs[1, 0].set_ylabel("Mass Flow (kg/s)")

axs[1, 1].plot(time[0:len(Thrust_array)], OF_array)
axs[1, 1].set_title("OF Ratio")
axs[1, 1].set_xlabel("Time(s)")
axs[1, 1].set_ylabel("OF Ratio")

# Adjust layout
plt.tight_layout()

# WRITE TO .ENG FILE
file_path = "RocketPy/data/motors/LE2.eng"  # Specify the desired file path

if not os.path.exists(file_path):
    f = open(file_path, "x")
    f.close()

# Open the file for writing
with open(file_path, "w") as f:
    f.write("; ALULA - LE2 \n")
    f.write("; 10/7/2023 ver. \n")
    f.write("; created by UCB STAR \n")
    f.write("LE2 98 732 0 6.325 8.98822 ALULA\n")

    for i in range(len(Thrust_array)):
        f.write(f"{str(time[i])} {str(Thrust_array[i] * 1000)}\n")  # Thrust_array values in N

# Display the plots
# %matplotlib inline
plt.show()
# Out:
# TIMESTEP 0.08032128514056225
# OF RATIO ERROR
# CSTAR ZERO
# PC = 176.15210223737304
# OF RATIO ERROR
# =================  WARNING  ==========================
#  Bad Solution in CalcPCoPE
#  (desired Area Ratio= 4.35   actual= inf )
#  input gam= 0.0  eps= 4.35
# =================  WARNING  ==========================
# Thrust 0.0
# massflow 0.10492928390769844
# OX_INJ: 12.328642564412496
# OX_FEED_dP: 47.24878447807614
# OF RATIO ERROR
# OF RATIO ERROR
# Thrust 0.255400584265176
# massflow 0.13640083190775817
# OX_INJ: 13.285153987639646
# OX_FEED_dP: 50.914557238601546
# OF RATIO ERROR
# OF RATIO ERROR
# Thrust 0.30054139502044536
# massflow 0.151418813567311
# OX_INJ: 14.238911256660026
# OX_FEED_dP: 54.56977486802839
# Thrust 0.48445063841695646
# massflow 0.264720464970436
# OX_INJ: 27.841045180851086
# OX_FEED_dP: 106.699138734995
# /tmp/ipykernel_218/1257844181.py:90: RuntimeWarning: divide by zero encountered in divide
#   OF_ratio = mdot_ox/mdot_eth
# /tmp/ipykernel_218/1257844181.py:97: RuntimeWarning: divide by zero encountered in divide
#   mdot_CEA_res = Pc*6895*At/(abs(Cstar)*Efficiency)
# /tmp/ipykernel_218/1257844181.py:102: RuntimeWarning: invalid value encountered in divide
#   error = (mdot_CEA_res-mdot_fluid)/mdot_CEA_res
# Thrust 0.483421506904296
# massflow 0.26430522073060814
# OX_INJ: 27.75718712324392
# OX_FEED_dP: 106.3777577500301
# Thrust 0.4823972789640381
# massflow 0.2638918825606359
# OX_INJ: 27.67383170590275
# OX_FEED_dP: 106.05830310379015
# Thrust 0.481377900553329
# massflow 0.26348043592697273
# OX_INJ: 27.59097440072787
# OX_FEED_dP: 105.74075744260418
# Thrust 0.48036337516735395
# massflow 0.263070866281281
# OX_INJ: 27.508610707034116
# OX_FEED_dP: 105.42510351786572
# Thrust 0.4793536390623956
# massflow 0.26266315933998463
# OX_INJ: 27.426736195719776
# OX_FEED_dP: 105.11132435530767
# Thrust 0.47834864754293294
# massflow 0.2622573009356036
# OX_INJ: 27.345346485059288
# OX_FEED_dP: 104.7994031622291
# Thrust 0.4773484076528631
# massflow 0.2618532770817452
# OX_INJ: 27.26443725058057
# OX_FEED_dP: 104.48932336534976
# Thrust 0.47635282520211963
# massflow 0.26145107390605343
# OX_INJ: 27.18400421395933
# OX_FEED_dP: 104.18106856824792
# Thrust 0.47536189747001145
# massflow 0.26105067770322804
# OX_INJ: 27.104043150986435
# OX_FEED_dP: 103.87462258189498
# Thrust 0.4743755917126843
# massflow 0.2606520748806251
# OX_INJ: 27.024549882518897
# OX_FEED_dP: 103.56996938997567
# OF RATIO ERROR
# OF RATIO ERROR
# Thrust 0.4733938646329728
# massflow 0.2602552520670108
# OX_INJ: 26.945520291212613
# OX_FEED_dP: 103.26709321301524
# Thrust 0.47241668618038
# massflow 0.2598601958843517
# OX_INJ: 26.86695028511237
# OX_FEED_dP: 102.9659783688403
# OF RATIO ERROR
# OF RATIO ERROR
# Thrust 0.47144400283183413
# massflow 0.2594668932803914
# OX_INJ: 26.788835849627638
# OX_FEED_dP: 102.66660947177301
# Thrust 0.47047581383485687
# massflow 0.25907533120155757
# OX_INJ: 26.711172995619272
# OX_FEED_dP: 102.36897123367652
# Thrust 0.4695120573417306
# massflow 0.25868549685174586
# OX_INJ: 26.633957799666344
# OX_FEED_dP: 102.07304861827492
# Thrust 0.46855270499028095
# massflow 0.25829737730198654
# OX_INJ: 26.55718634251402
# OX_FEED_dP: 101.77882660525876
# Thrust 0.4675977436972118
# massflow 0.2579109601325879
# OX_INJ: 26.480854809207997
# OX_FEED_dP: 101.4862905740441
# Thrust 0.46664710368721146
# massflow 0.25752623289234766
# OX_INJ: 26.40495940400519
# OX_FEED_dP: 101.19542597767283
# Thrust 0.46570079742831244
# massflow 0.2571431829842593
# OX_INJ: 26.3294963323945
# OX_FEED_dP: 100.90621827390831
# Thrust 0.46475877466117466
# massflow 0.25676179843773117
# OX_INJ: 26.254461921012656
# OX_FEED_dP: 100.61865338480578
# Thrust 0.4638209942257983
# massflow 0.2563820670255339
# OX_INJ: 26.17985247972463
# OX_FEED_dP: 100.33271716814369
# Thrust 0.46288742904019614
# massflow 0.25600397674876585
# OX_INJ: 26.105664376814588
# OX_FEED_dP: 100.04839570558848
# Thrust 0.46195803921098905
# massflow 0.2556275159222252
# OX_INJ: 26.031894051720727
# OX_FEED_dP: 99.76567535150029
# Thrust 0.4610328273656816
# massflow 0.25525267264960405
# OX_INJ: 25.958537933423365
# OX_FEED_dP: 99.48454242015995
# Thrust 0.4601117260579947
# massflow 0.2548794353206945
# OX_INJ: 25.88559251714547
# OX_FEED_dP: 99.2049834797194
# Thrust 0.4591947274393906
# massflow 0.2545077924162585
# OX_INJ: 25.8130543337856
# OX_FEED_dP: 98.92698523505497
# Thrust 0.4582817924243392
# massflow 0.25413773275396667
# OX_INJ: 25.74091998743257
# OX_FEED_dP: 98.65053467154043
# Thrust 0.45737288573089996
# massflow 0.2537692448699841
# OX_INJ: 25.669186059853462
# OX_FEED_dP: 98.37561868900275
# Thrust 0.45646800833575607
# massflow 0.2534023177988056
# OX_INJ: 25.59784923015952
# OX_FEED_dP: 98.10222456033465
# Thrust 0.4555670858920589
# massflow 0.2530369403145429
# OX_INJ: 25.526906157929083
# OX_FEED_dP: 97.83033948357003
# Thrust 0.45467013165567133
# massflow 0.252673101457183
# OX_INJ: 25.45635356374341
# OX_FEED_dP: 97.559950890533
# Thrust 0.4537770998285817
# massflow 0.25231079037854526
# OX_INJ: 25.38618820520283
# OX_FEED_dP: 97.29104635492092
# Thrust 0.4528879527027683
# massflow 0.25194999663296835
# OX_INJ: 25.316406920931428
# OX_FEED_dP: 97.02361376094987
# Thrust 0.4520026765767698
# massflow 0.2515907093199691
# OX_INJ: 25.24700649948585
# OX_FEED_dP: 96.75764080095544
# Thrust 0.45637861912559713
# massflow 0.25123291793633995
# OX_INJ: 25.177983809159077
# OX_FEED_dP: 96.49311547285805
# Thrust 0.4555687918225729
# massflow 0.2508766123577399
# OX_INJ: 25.10933579459471
# OX_FEED_dP: 96.23002606718723
# Thrust 0.4547624436664405
# massflow 0.2505217819835871
# OX_INJ: 25.04105934663518
# OX_FEED_dP: 95.96836066828267
# Burn finished with 0.007096778490853772L LOX and 0.6510967784908539L ETH at Time 3.21285140562249s

# %% [markdown]
# ### Creating Environment
#
# ---

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
from rocketpy.environment import Environment
Env = Environment(
    latitude=32.9901,
    longitude=-106.9751,
    elevation=1400.556
)

tomorrow = datetime.date.today() + datetime.timedelta(days=1)

Env.set_date(
    (tomorrow.year, tomorrow.month, tomorrow.day, 12)
)  # Hour given in UTC time

Env.set_atmospheric_model(type='Forecast', file='GFS')

##Set custom wind speed
#Env.set_atmospheric_model(
 #   type="custom_atmosphere",
  #  pressure=None,
   # temperature=300,
    #wind_u=[(0, 7), (1000, 10)],
    #wind_v=[(0, 3), (500, 3), (1600, 2)],
#)

Env.wind_speed()
# Out:
# oc_open: server error retrieving url: code=0 message="/gfs_0p25/gfs20240224/gfs_0p25_18z is not an available dataset"

# %%
Env.info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7911 m/s²
# Acceleration of gravity at  79.091 km (ASL): 9.5561 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2024-02-25 12:00:00 UTC
# Launch Site Latitude: 32.99010°
# Launch Site Longitude: -106.97510°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 315458.79 W    3651921.75 N
# Launch Site UTM zone: 13S
# Launch Site Surface Elevation: 1471.3 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: Forecast
# Forecast Maximum Height: 79.091 km
# Forecast Time Period: From  2024-02-24 12:00:00  to  2024-03-11 12:00:00  UTC
# Forecast Hour Interval: 3  hrs
# Forecast Latitude Range: From  -90.0 ° To  90.0 °
# Forecast Longitude Range: From  0.0 ° To  359.75 °
#
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 0.87 m/s
# Surface Wind Direction: 1.95°
# Surface Wind Heading: 181.95°
# Surface Pressure: 854.80 hPa
# Surface Temperature: 286.95 K
# Surface Air Density: 1.038 kg/m³
# Surface Speed of Sound: 339.58 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6371.83 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots

# %% [markdown]
# ### Creating Thrust Curve
#
# ---

# %%
from rocketpy.motors.liquid_motor import LiquidMotor
from rocketpy.motors import CylindricalTank, Fluid, TankGeometry
from rocketpy.motors.tank import MassFlowRateBasedTank

oxidizer_liq = Fluid(name="LOX_l", density=1140.0)
oxidizer_gas = Fluid(name="LOX_g", density=1.43)
fuel_liq = Fluid(name="ethanol_l", density=789)
fuel_gas = Fluid(name="ethanol_g", density=1.59)

tanks_shape = CylindricalTank(0.1, 1, True)
tanks_shape.radius.plot(equal_axis=True)
tanks_shape.inverse_volume.plot()

oxidizer_tank = MassFlowRateBasedTank(
    name="oxidizer tank",
    geometry=tanks_shape,
    flux_time=5,
    initial_liquid_mass=V_oxinit/1000*rho_LOX,
    initial_gas_mass=0.01,
    liquid_mass_flow_rate_in=0,
    liquid_mass_flow_rate_out= "RocketPy/data/motors/liquid_motor_example/LE2_mass_flow_out.csv", #####UPDATE
    gas_mass_flow_rate_in=0,
    gas_mass_flow_rate_out=0,
    liquid=oxidizer_liq,
    gas=oxidizer_gas,
)

fuel_tank = MassFlowRateBasedTank(
    name="fuel tank",
    geometry=tanks_shape,
    flux_time=2, ######temp
    initial_liquid_mass=V_ethinit/1000*rho_ETH,
    initial_gas_mass=0.01,
    liquid_mass_flow_rate_in=0,
    liquid_mass_flow_rate_out= "RocketPy/data/motors/liquid_motor_example/LE2_mass_flow_out.csv", #####UPDATE
    gas_mass_flow_rate_in=0,
    gas_mass_flow_rate_out=0,
    liquid=fuel_liq,
    gas=fuel_gas,
)

# Add the tank to the LiquidMotor

Propmass = V_oxinit/1000*rho_LOX+V_ethinit/1000*rho_ETH
print(Propmass)

LiquidMotor.propellant_initial_mass = Propmass

LE2 = LiquidMotor(
            thrust_source="RocketPy/data/motors/LE2.eng",
            dry_mass=12.685,
            center_of_dry_mass_position=1.107,
            dry_inertia=(7.332,7.333,0.0318,-0.00153,0.0219,0.0284),
            nozzle_radius=0.0515/2,
           # burn_time,
            nozzle_position=0,
            reshape_thrust_curve=False,
            interpolation_method="linear",
            coordinate_system_orientation="nozzle_to_combustion_chamber",
)

# Add tanks to the LiquidMotor
LE2.add_tank(tank=oxidizer_tank, position=0.8) #distance from nozzle outlet
LE2.add_tank(tank=fuel_tank, position=1.86)

oxidizer_tank.fluid_mass.plot()
oxidizer_tank.net_mass_flow_rate.plot()

fuel_tank.fluid_mass.plot()
fuel_tank.net_mass_flow_rate.plot()
# Out:
# Warning: Adding spherical caps to the tank will not modify the total height of the tank 1 m. Its cylindrical portion height will be reduced to 0.8 m.
# 7.3815

# %%
LE2.info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.02575 m
#
# Motor Details
# Total Burning Time: 18.955823293172692 s
# Total Propellant Mass: 7.381 kg
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/lib/python3.9/site-packages/rocketpy/mathutils/function.py:3331, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3329 try:
#    3330     # If cache is ready, return it
# -> 3331     val = cache[self.attrname]
#    3332 except KeyError:
#    3333     # If cache is not ready, create it
#
# KeyError: 'exhaust_velocity'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /srv/conda/lib/python3.9/site-packages/rocketpy/mathutils/function.py:3336, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3334 try:
#    3335     # Handle methods which return Function instances
# -> 3336     val = self.func(instance).reset(*args, **kwargs)
#    3337 except AttributeError:
#    3338     # Handle methods which return a valid source
#
# AttributeError: 'numpy.ndarray' object has no attribute 'reset'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 LE2.info()
#
# File /srv/conda/lib/python3.9/site-packages/rocketpy/motors/liquid_motor.py:480, in LiquidMotor.info(self)
#     478 def info(self):
#     479     """Prints out basic data about the Motor."""
# --> 480     self.prints.all()
#     481     self.plots.thrust()
#     482     return None
#
# File /srv/conda/lib/python3.9/site-packages/rocketpy/prints/liquid_motor_prints.py:88, in _LiquidMotorPrints.all(self)
#      81 """Prints out all data available about the LiquidMotor.
#      82
#      83 Returns
#      84 -------
#      85 None
#      86 """
#      87 self.nozzle_details()
# ---> 88 self.motor_details()
#      89 return None
#
# File /srv/conda/lib/python3.9/site-packages/rocketpy/prints/liquid_motor_prints.py:57, in _LiquidMotorPrints.motor_details(self)
#      48 print("Total Burning Time: " + str(self.liquid_motor.burn_duration) + " s")
#      49 print(
#      50     "Total Propellant Mass: "
#      51     + "{:.3f}".format(self.liquid_motor.propellant_initial_mass)
#      52     + " kg"
#      53 )
#      54 print(
#      55     "Average Propellant Exhaust Velocity: "
#      56     + "{:.3f}".format(
# ---> 57         self.liquid_motor.exhaust_velocity.average(*self.liquid_motor.burn_time)
#      58     )
#      59     + " m/s"
#      60 )
#      61 print(
#      62     "Average Thrust: "
#      63     + "{:.3f}".format(self.liquid_motor.average_thrust)
#      64     + " N"
#      65 )
#      66 print(
#      67     "Maximum Thrust: "
#      68     + str(self.liquid_motor.max_thrust)
#    (...)
#      71     + " s after ignition."
#      72 )
#
# File /srv/conda/lib/python3.9/site-packages/rocketpy/mathutils/function.py:3340, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3337 except AttributeError:
#    3338     # Handle methods which return a valid source
#    3339     source = self.func(instance)
# -> 3340     val = Function(source, *args, **kwargs)
#    3341 except TypeError:
#    3342     # Handle methods which are the source themselves
#    3343     def source_function(*_):
#
# File /srv/conda/lib/python3.9/site-packages/rocketpy/mathutils/function.py:118, in Function.__init__(self, source, inputs, outputs, interpolation, extrapolation, title)
#     115 if outputs is None:
#     116     outputs = ["Scalar"]
# --> 118 inputs, outputs, interpolation, extrapolation = self._check_user_input(
#     119     source, inputs, outputs, interpolation, extrapolation
#     120 )
#     122 # initialize variables to avoid errors when being called by other methods
#     123 self.get_value_opt = None
#
# File /srv/conda/lib/python3.9/site-packages/rocketpy/mathutils/function.py:3125, in Function._check_user_input(source, inputs, outputs, interpolation, extrapolation)
#    3123     in_out_dim = len(inputs) + len(outputs)
#    3124     if source_dim != in_out_dim:
# -> 3125         raise ValueError(
#    3126             f"Source dimension ({source_dim}) does not match input "
#    3127             + f"and output dimension ({in_out_dim})."
#    3128         )
#    3129 return inputs, outputs, interpolation, extrapolation
#
# ValueError: Source dimension (474) does not match input and output dimension (2).

# %% [markdown]
# ### Creating a Rocket
#
# ---

# %%
from rocketpy.rocket.rocket import Rocket
ALULA = Rocket(
        #self,
        radius=0.0785,
        mass=36.338, #*0.9,     #  total dry
        inertia=(40.32089762,40.32707615,0.16968255,-0.00501791,-0.33114339,0.44168709),
        power_off_drag="RocketPy/data/LE2_Inserts_Drag_-_Sheet1.csv", ##UPDATE
        power_on_drag="RocketPy/data/LE2_Inserts_Drag_-_Sheet1.csv", ##UPDATE
        center_of_mass_without_motor=1.996,
        coordinate_system_orientation="tail_to_nose",
)

ALULA.add_motor(LE2, position=0) # origin = nozzle outlet


railButtons = ALULA.set_rail_buttons(
    upper_button_position=0.18,
    lower_button_position=-1.4246,
    angular_position=60,
)

NoseCone = ALULA.add_nose(length=0.762, kind="vonKarman", position=3.99)

FinSet = ALULA.add_trapezoidal_fins(
    n=3,
    root_chord =0.305,
    tip_chord=0.102,
    span=0.152,
    position=0.4,
    sweep_angle=33.7
)

# %% [markdown]
# To add the motor to our rocket we need only inform what motor we are adding (Pro75M1670) and inform the position, in meters, of the motor's nozzle exit area relative to the previously defined coordinate system.

# %%
ALULA.info()
# Out:
# Inertia Details
#
# Rocket Mass: 36.338 kg (without motor)
# Rocket Dry Mass: 49.023 kg (with unloaded motor)
# Rocket Loaded Mass: 56.425 kg (with loaded motor)
# Rocket Inertia (with unloaded motor) 11: 55.084 kg*m2
# Rocket Inertia (with unloaded motor) 22: 55.091 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.201 kg*m2
# Rocket Inertia (with unloaded motor) 12: -0.007 kg*m2
# Rocket Inertia (with unloaded motor) 13: -0.309 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.470 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.0785 m
# Rocket Frontal Area: 0.019359 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.230 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.766 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 1.000 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.131 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 6.707/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 3.609 m
# Fins Center of Pressure position: 0.303 m
#
# Stability
#
# Center of Mass position (time=0): 1.635 m
# Initial Static Margin (mach=0, time=0): 3.648 c
# Final Static Margin (mach=0, time=burn_out): 4.215 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.573 m

# %% [markdown]
# #### Adding Parachutes + Simulating flight
# ---

# %%
main = ALULA.add_parachute(
    name="main", #84"d - 120"d
    cd_s=3.464577329*2.2, #^7.07050353*2.2,
    trigger=259.07,  # ejection altitude: 1000ft
    sampling_rate=105,
    lag=0, #1.5
    noise=(0, 8.3, 0.5),
)

drogue = ALULA.add_parachute(
    name="drogue", #60''d
    cd_s=1.767638271*2.2,
    trigger="apogee",  # ejection at apogee
    sampling_rate=105,
    lag=0, #1.5
    noise=(0, 8.3, 0.5),
)

# %%
from rocketpy.simulation.flight import Flight
test_flight = Flight(
  rocket=ALULA, environment=Env, rail_length=18.288, inclination=85, heading=0
)

# %% [markdown]
# ## Analyzing the Results
# ---

# %%
test_flight.all_info()
# Out:
# Initial Conditions
#
# Position - x: 0.00 m | y: 0.00 m | z: 1471.33 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude - e0: 0.999 | e1: -0.044 | e2: -0.000 | e3: 0.000
# Euler Angles - Spin φ : 0.00° | Nutation θ: -5.00° | Precession ψ: 0.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s| ω3: 0.00 rad/s
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: -0.86 m/s
# Lateral Surface Wind Speed: 0.03 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 18.288  m
# Launch Rail Inclination: 85.00°
# Launch Rail Heading: 0.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 1.240 s
# Rail Departure Velocity: 28.012 m/s
# Rail Departure Stability Margin: 3.818 c
# Rail Departure Angle of Attack: 1.759°
# Rail Departure Thrust-Weight Ratio: 3.046
# Rail Departure Reynolds Number: 2.563e+05
#
#
# Burn out State
#
# Burn out time: 18.956 s
# Altitude at burn out: 1837.891 m (AGL)
# Rocket velocity at burn out: 138.531 m/s
# Freestream velocity at burn out: 144.168 m/s
# Mach Number at burn out: 0.432
# Kinetic energy at burn out: 4.919e+05 J
#
#
# Apogee State
#
# Apogee Altitude: 3962.917 m (ASL) | 2491.588 m (AGL)
# Apogee Time: 30.393 s
# Apogee Freestream Speed: 78.280 m/s
#
#
# Parachute Events
#
# Drogue Ejection Triggered at: 30.400 s
# Drogue Parachute Inflated at: 30.400 s
# Drogue Parachute Inflated with Freestream Speed of: 78.547 m/s
# Drogue Parachute Inflated at Height of: 2491.587 m (AGL)
# Main Ejection Triggered at: 188.933 s
# Main Parachute Inflated at: 188.933 s
# Main Parachute Inflated with Freestream Speed of: 13.485 m/s
# Main Parachute Inflated at Height of: 259.535 m (AGL)
#
#
# Impact Conditions
#
# X Impact: 1548.214 m
# Y Impact: 982.775 m
# Latitude: 32.9989361°
# Longitude: -106.9585006°
# Time of Impact: 215.836 s
# Velocity at Impact: -9.492 m/s
#
#
# Stability Margin
#
# Maximum Stability Margin: 4.285 c at 18.96 s
# Minimum Stability Margin: 3.648 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 138.531 m/s at 18.96 s
# Maximum Mach Number: 0.432 Mach at 18.96 s
# Maximum Reynolds Number: 1.123e+06 at 17.42 s
# Maximum Dynamic Pressure: 8.934e+03 Pa at 18.96 s
# Maximum Acceleration During Motor Burn: 25.704 m/s² at 0.01 s
# Maximum Gs During Motor Burn: 2.621 g at 0.01 s
# Maximum Acceleration After Motor Burn: 5.770 m/s² at 9.30 s
# Maximum Gs After Motor Burn: 0.588 g at 9.30 s
# Maximum Stability Margin: 4.285 c at 18.96 s
# Maximum Upper Rail Button Normal Force: 1.010 N
# Maximum Upper Rail Button Shear Force: 0.548 N
# Maximum Lower Rail Button Normal Force: 0.852 N
# Maximum Lower Rail Button Shear Force: 0.461 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.000000 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.000000e+00 s
# Relative Error Tolerance:  1e-06
# Absolute Error Tolerance:  [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot:  True
# Terminate Simulation on Apogee:  False
# Number of Time Steps Used:  549
# Number of Derivative Functions Evaluation:  1622
# Average Function Evaluations per Time Step: 2.954463
#
#
#
# Trajectory 3d Plot
# Trajectory Kinematic Plots
# Angular Position Plots
# Path, Attitude and Lateral Attitude Angle plots
# Trajectory Angular Velocity and Acceleration Plots
# Aerodynamic Forces Plots
# Rail Buttons Forces Plots
# Trajectory Energy Plots
# Trajectory Fluid Mechanics Plots
# Trajectory Stability and Control Plots
# Rocket and Parachute Pressure Plots
# Parachute:  main
# Parachute:  drogue

# %% [markdown]
# Export Flight Trajectory to a .kml file so it can be opened on Google Earth

# %%
test_flight.export_kml(
    file_name="trajectory.kml",
    extrude=True,
    altitude_mode="relative_to_ground",
)
# Out:
# File  trajectory.kml  saved with success!

# %% [markdown]
# ### Apogee as a Function of Mass
# ---

# %%
from rocketpy.utilities import apogee_by_mass

apogee_by_mass(flight=test_flight, min_mass=30, max_mass=40, points=10, plot=True)
# Out:
# 'Function from R1 to R1 : (Rocket Mass without motor (kg)) → (Apogee AGL (m))'

# %% [markdown]
# ### Out of Rail Speed as a Function of Mass
#
#  A common rule of thumb is that our rocket's out of rail speed should be 4 times the wind speed so that it does not stall and become unstable.

# %%
from rocketpy.utilities import liftoff_speed_by_mass

liftoff_speed_by_mass(flight=test_flight, min_mass=5, max_mass=20, points=10, plot=True)
# Out:
# 'Function from R1 to R1 : (Rocket Mass without motor (kg)) → (Out of Rail Speed (m/s))'

# %% [markdown]
# ### Dynamic Stability Analysis
#
#  Different static margins result in different dynamic behavior, which also depends on the rocket's rotational inertial. dynamic stability of ALULA varies if we change the fins span by a certain factor.

# %%
# Helper class
from rocketpy import Function
import copy

# Prepare a copy of the rocket
ALULA2 = copy.deepcopy(ALULA)

# Prepare Environment Class
custom_env = Environment()
custom_env.set_atmospheric_model(type="custom_atmosphere", wind_v=-5)

# Simulate Different Static Margins by Varying Fin Position
simulation_results = []

for factor in [-0.5, -0.2, 0.1, 0.4, 0.7]:
    # Modify rocket fin set by removing previous one and adding new one
    ALULA2.aerodynamic_surfaces.pop(-1)

    fin_set = ALULA2.add_trapezoidal_fins(
        n=4,
        root_chord=0.120,
        tip_chord=0.040,
        span=0.100,
        position=-1.04956 * factor,
    )
    # Simulate
    print(
        "Simulating Rocket with Static Margin of {:1.3f}->{:1.3f} c".format(
            ALULA2.static_margin(0),
            ALULA2.static_margin(ALULA2.motor.burn_out_time),
        )
    )
    test_flight = Flight(
        rocket=ALULA2,
        environment=custom_env,
        rail_length=5.2,
        inclination=90,
        heading=0,
        max_time_step=0.01,
        max_time=5,
        terminate_on_apogee=True,
        verbose=True,
    )
    # Store Results
    static_margin_at_ignition = ALULA2.static_margin(0)
    static_margin_at_out_of_rail = ALULA2.static_margin(test_flight.out_of_rail_time)
    static_margin_at_steady_state = ALULA2.static_margin(test_flight.t_final)
    simulation_results += [
        (
            test_flight.attitude_angle,
            "{:1.2f} c | {:1.2f} c | {:1.2f} c".format(
                static_margin_at_ignition,
                static_margin_at_out_of_rail,
                static_margin_at_steady_state,
            ),
        )
    ]

Function.compare_plots(
    simulation_results,
    lower=0,
    upper=1.5,
    xlabel="Time (s)",
    ylabel="Attitude Angle (deg)",
)

# %% [markdown]
# ### Characteristic Frequency Calculation
#
# characteristic frequency of oscillation of our rocket just as it leaves the launch rail

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate first 5 seconds of Flight
flight = Flight(
    rocket=ALULA,
    environment=Env,
    rail_length=5.2,
    inclination=90,
    heading=0,
    max_time_step=0.01,
    max_time=5,
)

# Perform a Fourier Analysis
Fs = 100.0
# sampling rate
Ts = 1.0 / Fs
# sampling interval
t = np.arange(1, 400, Ts)  # time vector
ff = 5
# frequency of the signal
y = flight.attitude_angle(t) - np.mean(flight.attitude_angle(t))
n = len(y)  # length of the signal
k = np.arange(n)
T = n / Fs
frq = k / T  # two sides frequency range
frq = frq[range(n // 2)]  # one side frequency range
Y = np.fft.fft(y) / n  # fft computing and normalization
Y = Y[range(n // 2)]

# Create the plot
fig, ax = plt.subplots(2, 1)
ax[0].plot(t, y)
ax[0].set_xlabel("Time")
ax[0].set_ylabel("Signal")
ax[0].set_xlim((0, 5))
ax[0].grid()
ax[1].plot(frq, abs(Y), "r")  # plotting the spectrum
ax[1].set_xlabel("Freq (Hz)")
ax[1].set_ylabel("|Y(freq)|")
ax[1].set_xlim((0, 5))
ax[1].grid()
plt.subplots_adjust(hspace=0.5)
plt.show()
